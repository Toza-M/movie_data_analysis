# %%
import pandas as pd

financial = pd.read_csv("movies_financial.csv")
imdb = pd.read_csv("imdb_data.csv")

financial["Title_clean"] = financial["Title"].str.lower().str.strip()
imdb["Title_clean"] = imdb["Title"].str.lower().str.strip()

financial["Release Date"] = pd.to_datetime(
    financial["Release Date"],
    errors="coerce",
    format="mixed"
)


financial["Year"] = financial["Release Date"].dt.year

merged = pd.merge(
    financial,
    imdb,
    how="inner",
    on=["Title_clean", "Year"]
)
merged = pd.merge(financial, imdb, on=["Title_clean", "Year"], how="inner")
merged = merged.drop(columns=["Title_y"])
merged = merged.rename(columns={"Title_x": "Title"})


merged.drop(columns=["Title_clean"], inplace=True)

merged.to_csv("movies_dataset_final.csv", index=False)
df=pd.read_csv("movies_dataset_final.csv")
df
# Out:
#      Release Date                                        Title        Budget  \
# 0      2019-04-23                            Avengers: Endgame  $400,000,000
# 1      2022-12-09                     Avatar: The Way of Water  $400,000,000
# 2      2011-05-20  Pirates of the Caribbean: On Stranger Tides  $379,000,000
# 3      2015-04-22                      Avengers: Age of Ultron  $365,000,000
# 4      2023-05-17                                       Fast X  $340,000,000
# ...           ...                                          ...           ...
# 2572   2017-10-11                              Happy Death Day    $5,000,000
# 2573   1987-02-27  A Nightmare On Elm Street 3: Dream Warriors    $5,000,000
# 2574   2015-08-06                                     The Gift    $5,000,000
# 2575   2017-06-23                                 The Big Sick    $5,000,000
# 2576   1975-05-16               The Return of the Pink Panther    $5,000,000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2577 entries, 0 to 2576
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Release Date     2577 non-null   object
#  1   Title            2577 non-null   object
#  2   Budget           2577 non-null   object
#  3   Domestic Gross   2577 non-null   object
#  4   Worldwide Gross  2577 non-null   object
#  5   Year             2577 non-null   float64
#  6   Rating           2577 non-null   float64
#  7   Vote Count       2577 non-null   int64
#  8   Language         2577 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 181.3+ KB

# %%
import pandas as pd

merged = pd.read_csv("movies_dataset_final.csv")
merged["Release Date"] = pd.to_datetime(merged["Release Date"], errors="coerce")

merged["Year"] = merged["Release Date"].dt.year
def get_season(month):
    if month in [12, 1, 2]:
        return "Winter"
    elif month in [3, 4, 5]:
        return "Spring"
    elif month in [6, 7, 8]:
        return "Summer"
    elif month in [9, 10, 11]:
        return "Fall"
    else:
        return None

merged["Season"] = merged["Release Date"].dt.month.apply(get_season)
merged.to_csv("movies_dataset_final.csv", index=False)
