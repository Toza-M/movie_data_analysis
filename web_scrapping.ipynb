# %% [markdown]
# ### Try scrapping the data from The Numbers site

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
The_Numbers_url = "https://www.the-numbers.com/movie/budgets/all"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# %% [markdown]
# ### Function to scrape the data

# %%
def scrape_The_Numbers():
    
    
    all_movies = []
    
    for start_index in range(1, 5001, 100): # Starf from 1 to ignore the headers, collect 5000 movies, 100 per page
        
        
        if start_index == 1:
            url = The_Numbers_url
        else:
            url = f"{The_Numbers_url}/{start_index}"  # this condition to handle the first page differently and go thorough multiple pages
            
        print(f"Scraping page starting at row {start_index}...")
        
        try:   # Exception handling to catch any errors during requests or parsing
            response = requests.get(url, headers=headers)
            if response.status_code != 200:
                print("Failed to load page.")
                continue

            page = BeautifulSoup(response.content, 'html.parser')
            rows = page.find_all('tr')
            
            current_page_count = 0
            
            for row in rows:
                cols = row.find_all('td')
                if len(cols) >= 6:
                    data = {
                        "Release Date": cols[1].get_text(strip=True),
                        "Title": cols[2].get_text(strip=True),
                        "Budget": cols[3].get_text(strip=True),
                        "Domestic Gross": cols[4].get_text(strip=True),
                        "Worldwide Gross": cols[5].get_text(strip=True)
                    }
                    all_movies.append(data)
                    current_page_count += 1
            
            print(f" -> Collected {current_page_count} movies.")
            
            time.sleep(2)  # to handle the robot detection by adding delay between requests
            
        except Exception as e:
            print(f"Error on page {start_index}: {e}")

    return all_movies

# %%
# --- RUN IT ---
data = scrape_The_Numbers()
df = pd.DataFrame(data)

df.head()
# Out:
# Scraping page starting at row 1...
#  -> Collected 100 movies.
# Scraping page starting at row 101...
#  -> Collected 100 movies.
# Scraping page starting at row 201...
#  -> Collected 100 movies.
# Scraping page starting at row 301...
#  -> Collected 100 movies.
# Scraping page starting at row 401...
#  -> Collected 100 movies.
# Scraping page starting at row 501...
#  -> Collected 100 movies.
# Scraping page starting at row 601...
#  -> Collected 100 movies.
# Scraping page starting at row 701...
#  -> Collected 100 movies.
# Scraping page starting at row 801...
#  -> Collected 100 movies.
# Scraping page starting at row 901...
#  -> Collected 100 movies.
# Scraping page starting at row 1001...
#  -> Collected 100 movies.
# Scraping page starting at row 1101...
#  -> Collected 100 movies.
# Scraping page starting at row 1201...
#  -> Collected 100 movies.
# Scraping page starting at row 1301...
#  -> Collected 100 movies.
# Scraping page starting at row 1401...
#  -> Collected 100 movies.
# Scraping page starting at row 1501...
#  -> Collected 100 movies.
# Scraping page starting at row 1601...
#  -> Collected 100 movies.
# Scraping page starting at row 1701...
#  -> Collected 100 movies.
# Scraping page starting at row 1801...
#  -> Collected 100 movies.
# Scraping page starting at row 1901...
#  -> Collected 100 movies.
# Scraping page starting at row 2001...
#  -> Collected 100 movies.
# Scraping page starting at row 2101...
#  -> Collected 100 movies.
# Scraping page starting at row 2201...
#  -> Collected 100 movies.
# Scraping page starting at row 2301...
#  -> Collected 0 movies.
# Scraping page starting at row 2401...
#  -> Collected 100 movies.
# Scraping page starting at row 2501...
#  -> Collected 100 movies.
# Scraping page starting at row 2601...
#  -> Collected 100 movies.
# Scraping page starting at row 2701...
#  -> Collected 100 movies.
# Scraping page starting at row 2801...
#  -> Collected 100 movies.
# Scraping page starting at row 2901...
#  -> Collected 100 movies.
# Scraping page starting at row 3001...
#  -> Collected 100 movies.
# Scraping page starting at row 3101...
#  -> Collected 100 movies.
# Scraping page starting at row 3201...
#  -> Collected 100 movies.
# Scraping page starting at row 3301...
#  -> Collected 100 movies.
# Scraping page starting at row 3401...
#  -> Collected 100 movies.
# Scraping page starting at row 3501...
#  -> Collected 100 movies.
# Scraping page starting at row 3601...
#  -> Collected 100 movies.
# Scraping page starting at row 3701...
#  -> Collected 100 movies.
# Scraping page starting at row 3801...
#  -> Collected 100 movies.
# Scraping page starting at row 3901...
#  -> Collected 100 movies.
# Scraping page starting at row 4001...
#  -> Collected 100 movies.
# Scraping page starting at row 4101...
#  -> Collected 100 movies.
# Scraping page starting at row 4201...
#  -> Collected 100 movies.
# Scraping page starting at row 4301...
#  -> Collected 100 movies.
# Scraping page starting at row 4401...
#  -> Collected 100 movies.
# Scraping page starting at row 4501...
#  -> Collected 100 movies.
# Scraping page starting at row 4601...
#  -> Collected 0 movies.
# Scraping page starting at row 4701...
#  -> Collected 100 movies.
# Scraping page starting at row 4801...
#  -> Collected 100 movies.
# Scraping page starting at row 4901...
#  -> Collected 100 movies.
#    Release Date                                        Title        Budget  \
# 0  Dec 16, 2015         Star Wars Ep. VII: The Force Awakens  $533,200,000
# 1  Apr 23, 2019                            Avengers: Endgame  $400,000,000
# 2   Dec 9, 2022                     Avatar: The Way of Water  $400,000,000
# 3  May 17, 2025      Mission: Impossible—The Final Reckoning  $400,000,000
# 4  May 20, 2011  Pirates of the Caribbean: On Stranger Tides  $379,000,000
#
#   Domestic Gross Worldwide Gross
# 0   $936,662,225  $2,056,046,835
# 1   $858,373,000  $2,717,503,922
# 2   $688,809,501  $2,322,902,023
# 3   $197,413,515    $591,353,074
# 4   $241,071,802  $1,045,713,802

# %%
df.to_csv("data\movies_financial.csv", index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\HP\AppData\Local\Temp\ipykernel_5356\4152102216.py:1: SyntaxWarning: invalid escape sequence '\m'
#   df.to_csv("data\movies_financial.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4800 entries, 0 to 4799
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Release Date     4800 non-null   object
#  1   Title            4800 non-null   object
#  2   Budget           4800 non-null   object
#  3   Domestic Gross   4800 non-null   object
#  4   Worldwide Gross  4800 non-null   object
# dtypes: object(5)
# memory usage: 187.6+ KB

# %% [markdown]
# ### Try to scrapping the IMDB movies

# %%
API_KEY = "6b1c54551e0e2df55b6bdf448af1b9f1" 

def scrape_top_movies():
    all_movies = []
    print("Starting collection movies...")
    for page_num in range(1, 401):
        url = f"https://api.themoviedb.org/3/movie/top_rated?api_key={API_KEY}&language=en-US&page={page_num}"
        
        try:
            response = requests.get(url)
            response.raise_for_status()
            data = response.json()
            for item in data['results']:
                all_movies.append({
                    "Title": item.get('title'),
                    "Year": item.get('release_date', 'N/A')[:4],
                    "Rating": item.get('vote_average'),      
                    "Vote Count": item.get('vote_count'),
                    "Language": item.get('original_language')
                })
            print(f"Page {page_num}/400 done. Total movies: {len(all_movies)}")
            time.sleep(0.2)
            
        except Exception as e:
            print(f"Error on page {page_num}: {e}")
            continue

    return all_movies

# %%
data = scrape_top_movies()
# Out:
# Starting collection movies...
# Page 1/400 done. Total movies: 20
# Page 340/400 done. Total movies: 6800
# Page 341/400 done. Total movies: 6820
# Page 342/400 done. Total movies: 6840
# Page 343/400 done. Total movies: 6860
# Page 344/400 done. Total movies: 6880
# Page 345/400 done. Total movies: 6900
# Page 346/400 done. Total movies: 6920
# Page 347/400 done. Total movies: 6940
# Page 348/400 done. Total movies: 6960
# Page 349/400 done. Total movies: 6980
# Page 350/400 done. Total movies: 7000
# Page 351/400 done. Total movies: 7020
# Page 352/400 done. Total movies: 7040
# Page 353/400 done. Total movies: 7060
# Page 354/400 done. Total movies: 7080
# Page 355/400 done. Total movies: 7100
# Page 356/400 done. Total movies: 7120
# Page 357/400 done. Total movies: 7140
# Page 358/400 done. Total movies: 7160
# Page 359/400 done. Total movies: 7180
# Page 360/400 done. Total movies: 7200
# Page 361/400 done. Total movies: 7220
# Page 362/400 done. Total movies: 7240
# Page 363/400 done. Total movies: 7260
# Page 364/400 done. Total movies: 7280
# Page 365/400 done. Total movies: 7300
# Page 366/400 done. Total movies: 7320
# Page 367/400 done. Total movies: 7340
# Page 368/400 done. Total movies: 7360
# Page 369/400 done. Total movies: 7380
# Page 370/400 done. Total movies: 7400
# Page 371/400 done. Total movies: 7420
# Page 372/400 done. Total movies: 7440
# Page 373/400 done. Total movies: 7460
# Page 374/400 done. Total movies: 7480
# Page 375/400 done. Total movies: 7500
# Page 376/400 done. Total movies: 7520
# Page 377/400 done. Total movies: 7540
# Page 378/400 done. Total movies: 7560
# Page 379/400 done. Total movies: 7580
# Page 380/400 done. Total movies: 7600
# Page 381/400 done. Total movies: 7620
# Page 382/400 done. Total movies: 7640
# Page 383/400 done. Total movies: 7660
# Page 384/400 done. Total movies: 7680
# Page 385/400 done. Total movies: 7700
# Page 386/400 done. Total movies: 7720
# Page 387/400 done. Total movies: 7740
# Page 388/400 done. Total movies: 7760
# Page 389/400 done. Total movies: 7780
# Page 390/400 done. Total movies: 7800
# Page 391/400 done. Total movies: 7820
# Page 392/400 done. Total movies: 7840
# Page 393/400 done. Total movies: 7860
# Page 394/400 done. Total movies: 7880
# Page 395/400 done. Total movies: 7900
# Page 396/400 done. Total movies: 7920
# Page 397/400 done. Total movies: 7940
# Page 398/400 done. Total movies: 7960
# Page 399/400 done. Total movies: 7980
# Page 400/400 done. Total movies: 8000

# %%
if data:
    df_imdb = pd.DataFrame(data)
    print(df_imdb.head())
else:
    print("None")
# Out:
#                       Title  Year  Rating  Vote Count Language
# 0  The Shawshank Redemption  1994   8.713       29336       en
# 1             The Godfather  1972   8.685       22140       en
# 2     The Godfather Part II  1974   8.571       13384       en
# 3          Schindler's List  1993   8.566       16896       en
# 4              12 Angry Men  1957   8.500        9579       en

# %%
df_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       8000 non-null   object
#  1   Year        8000 non-null   object
#  2   Rating      8000 non-null   float64
#  3   Vote Count  8000 non-null   int64
#  4   Language    8000 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 312.6+ KB

# %%
df_imdb.to_csv("data\imdb_data.csv", index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\HP\AppData\Local\Temp\ipykernel_5356\3445729527.py:1: SyntaxWarning: invalid escape sequence '\i'
#   df_imdb.to_csv("data\imdb_data.csv", index=False)
